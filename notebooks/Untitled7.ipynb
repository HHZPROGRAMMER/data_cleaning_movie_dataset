# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('moviesTMBD.csv')
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    Unnamed: 0       id                     title  popularity  adult  \
# 0           0  1007757                   Swapped    327.5134  False
# 1           1      278  The Shawshank Redemption     65.3308  False
# 2           2      238             The Godfather     47.2346  False
# 3           3   687163         Project Hail Mary    422.0199  False
# 4           4      240     The Godfather Part II     27.6763  False
#
#   original_language                                           overview  \
# 0                en  A small woodland creature and a majestic bird,...
# 1                en  Imprisoned in the 1940s for the double murder ...
# 2                en  Spanning the years 1945 to 1955, a chronicle o...
# 3                en  Science teacher Ryland Grace wakes up on a spa...
# 4                en  In the continuing saga of the Corleone crime f...
#
#   release_date  vote_average  vote_count
# 0   2026-05-01         8.987        1320
# 1   1994-09-23         8.721       30387
# ...

# %%
df=df.dropna(subset=["overview", "release_date"])
df.isnull().sum()
# Out:
# Unnamed: 0           0
# id                   0
# title                0
# popularity           0
# adult                0
# original_language    0
# overview             0
# release_date         0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
df=df.drop_duplicates()
df.head(3)
# Out:
#    Unnamed: 0       id                     title  popularity  adult  \
# 0           0  1007757                   Swapped    327.5134  False
# 1           1      278  The Shawshank Redemption     65.3308  False
# 2           2      238             The Godfather     47.2346  False
#
#   original_language                                           overview  \
# 0                en  A small woodland creature and a majestic bird,...
# 1                en  Imprisoned in the 1940s for the double murder ...
# 2                en  Spanning the years 1945 to 1955, a chronicle o...
#
#   release_date  vote_average  vote_count
# 0   2026-05-01         8.987        1320
# 1   1994-09-23         8.721       30387
# 2   1972-03-14         8.686       22929

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'popularity', 'adult', 'original_language',
#        'overview', 'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df["release_date"]=pd.to_datetime(df["release_date"])

# %% [markdown]
# Cleaned Data set

# %%
df.to_csv("Cleaned_moviesTMBD.csv", index=False)

# %%
top_movies=df[df["vote_count"]>500].sort_values(by="vote_average", ascending=False)
top_movies
# Out:
#       Unnamed: 0       id                     title  popularity  adult  \
# 0              0  1007757                   Swapped    327.5134  False
# 1              1      278  The Shawshank Redemption     65.3308  False
# 2              2      238             The Godfather     47.2346  False
# 3              3   687163         Project Hail Mary    422.0199  False
# 6              6      389              12 Angry Men     22.8937  False
# ...          ...      ...                       ...         ...    ...
# 9975        9975   399173            The Assignment      2.1132  False
# 9979        9979   277355                    Everly      2.0746  False
# 9972        9972     9904                  The Wild      4.8729  False
# 9974        9974    13043                   Camping      0.9096  False
# 9963        9963       83                Open Water      2.0059  False
#
#      original_language                                           overview  \
# ...
